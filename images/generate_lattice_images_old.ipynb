# %%
import numpy as np
import matplotlib.pyplot as plt
import sisl

# %%
geom = sisl.geom.graphene()
#geom = sisl.geom.graphene_nanoribbon(9)
#plot = geom.__plot__(show_cell=False, show_atoms=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 geom = sisl.geom.graphene()
#       2 #geom = sisl.geom.graphene_nanoribbon(9)
# ----> 3 plot = geom.__plot__(show_cell=False, show_atoms=False)
#
# File ~/miniconda3/envs/general-science-tools/lib/python3.12/site-packages/sisl/geometry.py:4506, in Geometry.__plot__(self, axis, lattice, axes, atom_indices, *args, **kwargs)
#    4504 # Start by plotting the supercell
#    4505 if lattice:
# -> 4506     axes = self.lattice.__plot__(axis, axes=axes, *args, **kwargs)
#    4508 # Create short-hand
#    4509 xyz = self.xyz
#
# File ~/miniconda3/envs/general-science-tools/lib/python3.12/site-packages/sisl/lattice.py:1406, in Lattice.__plot__(self, axis, axes, *args, **kwargs)
#    1404 else:
#    1405     for vv in v:
# -> 1406         axes.plot(vv[:, 0], vv[:, 1], *args, **kwargs)
# ...
